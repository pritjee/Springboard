# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT firstname, surname, recommendedby
        FROM Members
        ORDER BY firstname, surname;

        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Anna', 'Mackenzie', '1')
# ('Anne', 'Baker', '9')
# ('Burton', 'Tracy', '')
# ('Charles', 'Owen', '1')
# ('Darren', 'Smith', '')
# ('Darren', 'Smith', '')
# ('David', 'Farrell', '')
# ('David', 'Jones', '4')
# ('David', 'Pinker', '13')
# ('Douglas', 'Jones', '11')
# ('Erica', 'Crumpet', '2')
# ('Florence', 'Bader', '9')
# ('GUEST', 'GUEST', '')
# ('Gerald', 'Butters', '1')
# ('Henrietta', 'Rumney', '20')
# ('Henry', 'Worthington-Smyth', '2')
# ('Hyacinth', 'Tupperware', '')
# ('Jack', 'Smith', '1')
# ('Janice', 'Joplette', '1')
# ('Jemima', 'Farrell', '')
# ('Joan', 'Coplin', '16')
# ('John', 'Hunt', '30')
# ('Matthew', 'Genting', '5')
# ('Millicent', 'Purview', '2')
# ('Nancy', 'Dare', '4')
# ('Ponder', 'Stibbons', '6')
# ('Ramnaresh', 'Sarwin', '15')
# ('Tim', 'Boothe', '3')
# ('Tim', 'Rownam', '')
# ('Timothy', 'Baker', '13')
# ('Tracy', 'Smith', '')

# %% [markdown]
# q.10.Produce a report of members and who recommended them in alphabetic surname,firstname order

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT name, initialoutlay AS revenue
        FROM Facilities
        WHERE initialoutlay <1000;

        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Table Tennis', 320)
# ('Snooker Table', 450)
# ('Pool Table', 400)

# %% [markdown]
# q.12.Find the facilities with their usage by member, but not guests

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT f.facid, f.name, m.joindate
        FROM Facilities AS f
        JOIN Members AS m ON f.facid = m.memid
        WHERE memid <>0
        ORDER BY joindate;

        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (1, 'Tennis Court 2', '2012-07-02 12:02:05')
# (2, 'Badminton Court', '2012-07-02 12:08:23')
# (3, 'Table Tennis', '2012-07-03 09:32:15')
# (4, 'Massage Room 1', '2012-07-03 10:25:05')
# (5, 'Massage Room 2', '2012-07-09 10:44:09')
# (6, 'Squash Court', '2012-07-15 08:52:55')
# (7, 'Snooker Table', '2012-07-25 08:59:12')
# (8, 'Pool Table', '2012-07-25 16:02:35')

# %% [markdown]
# q.13.Find the facilities usage by month, but not guests

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT name, initialoutlay AS revenue
        FROM Facilities
        WHERE initialoutlay <1000;

        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Table Tennis', 320)
# ('Snooker Table', 450)
# ('Pool Table', 400)

# %% [markdown]
# q.10.Produce a list of facilities with a total revenue less than 1000.
